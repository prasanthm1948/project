# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
bank=pd.read_csv('/content/bank-additional-full-1 (2).csv',sep=";")

# %%
bank.info()

# %%
bank.head()

# %%
bank.tail()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
bank['y'].value_counts()

# %%
bank['y'].unique()

# %%
bank.shape

# %%
bank.describe()

# %%
bank.dropna(inplace=True)

# %%
bank.notnull()

# %%
from matplotlib import pyplot as plt

# %%
out_list=['age','duration','campaign','cons.conf.idx']
for i in out_list:
  q1=bank[i].quantile(0.25)
  q3=bank[i].quantile(0.75)
  iqr=q3-q1

# %%
bank=bank.drop_duplicates()
bank.head()

# %%
outliers=bank[bank['age']>70]
outliers

# %%
iqr=bank['age'].quantile(0.75)-bank['age'].quantile(0.25)
iqr

# %%
x=bank.iloc[:,:-1]
y=bank.iloc[:,-1]

# %%
x

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in x.columns:
  if x[i].dtype=='object':
    x[i]=le.fit_transform(x[i])
    print(le.classes_)

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
rfe=RFE(model)

# %%
rfe.fit(x,y)

# %%
x.head()

# %%
rfe.support_

# %%
selected_indices=[i for i,bank in enumerate(rfe.support_) if bank==True]
selected_indices

# %%
column_name= x.columns
selected_columns=[column_name[i] for i in selected_indices]
selected_columns

# %%
bank=pd.read_csv('/content/bank-additional-full-1 (2).csv',sep=";")
bank

# %%
X=x.loc[:,['marital',
 'education',
 'default',
 'contact',
 'month',
 'day_of_week',
 'previous',
 'poutcome',
 'cons.conf.idx',
 'euribor3m']]

# %%
x
# Out:
#         age  job  marital  education  default  housing  loan  contact  month  \
# 0      56.0    3        1          0        0        0     0        1      6
# 1      57.0    7        1          3        1        0     0        1      6
# 2      37.0    7        1          3        0        2     0        1      6
# 3      40.0    0        1          1        0        0     0        1      6
# 4      56.0    7        1          3        0        0     2        1      6
# ...     ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41184  46.0    1        1          5        0        0     0        0      7
# 41185  56.0    5        1          6        0        2     0        0      7
# 41186  44.0    9        1          5        0        0     0        0      7
# 41187  74.0    5        1          5        0        2     0        0      7
# 41193  94.0    5        1          5        0        2     0        0      7
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
x_train
# Out:
#        marital  education  default  contact  month  day_of_week  previous  \
# 33759        2          3        0        0      6            4       1.0
# 1731         1          6        1        1      6            0       0.0
# 17502        1          7        1        1      3            1       0.0
# 16861        2          1        1        0      3            2       0.0
# 11711        1          6        0        1      4            0       0.0
# ...        ...        ...      ...      ...    ...          ...       ...
# 6266         1          2        0        1      6            3       0.0
# 11285        1          2        0        1      4            2       0.0
# 38169        1          0        0        0      8            2       2.0
# 860          1          6        0        1      6            4       0.0
# 15798        2          2        1        0      3            1       0.0
#
#        poutcome  cons.conf.idx  euribor3m
# ...

# %%
x_train.shape
# Out:
# (30882, 10)

# %%
y_train
# Out:
# 33759    no
# 1731     no
# 17502    no
# 16861    no
# 11711    no
#          ..
# 6266     no
# 11285    no
# 38169    no
# 860      no
# 15798    no
# Name: y, Length: 30882, dtype: object

# %%
y_test.shape
# Out:
# (10295,)

# %%
x_test
# Out:
#        marital  education  default  contact  month  day_of_week  previous  \
# 36265        2          6        0        0      4            1       0.0
# 32672        1          2        0        0      6            1       1.0
# 40873        1          3        0        1      8            4       0.0
# 32907        1          3        0        0      6            1       1.0
# 16464        2          2        0        1      3            4       0.0
# ...        ...        ...      ...      ...    ...          ...       ...
# 3589         2          6        0        1      6            0       0.0
# 10596        2          6        0        1      4            3       0.0
# 1938         0          2        0        1      6            0       0.0
# 549          1          0        1        1      6            3       0.0
# 1975         1          0        0        1      6            0       0.0
#
#        poutcome  cons.conf.idx  euribor3m
# ...

# %%
y_test
# Out:
# 36265    yes
# 32672     no
# 40873     no
# 32907     no
# 16464     no
#         ...
# 3589      no
# 10596     no
# 1938      no
# 549       no
# 1975      no
# Name: y, Length: 10295, dtype: object

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8946090335114133

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[9016,   81],
#        [1004,  194]])

# %%
lr.predict([[94.0,5,1,5,0,2,0,0,7,0]])
# Out:
# array(['yes'], dtype=object)
